# %% [markdown]
# # Markdonw Language

# %% [markdown]
# #  1 - Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# # 2 - Block of Words
#  > This is a block of words a special text.

# %% [markdown]
# # 3 - Line breaks

# %% [markdown]
# > This is the part of the 40 days long course from Dr Ammar Tufail.This is a line break

# %% [markdown]
# # 4 - Combine two things

# %% [markdown]
# Block of words and heading.
#  > ## Heading

# %% [markdown]
# # 5 - Facce of text

# %% [markdown]
# **Bold**
# *Italic*
# ***Bold and italic***
# > Or you can use these symbols too.
# __Bold__
# _Italic_

# %% [markdown]
# # 6 - Bullet points / Lists

# %% [markdown]
# - Day - 1
# - Day - 2
# - Day - 3
# - Day - 4
# - Day - 5
#   - Day5 - a
#   - Day5 - b
#
# > Numbering of lists
# 1. Day 1
# 2. Day 2
# 3. Day 3
# > We can also use plus sign for lists
# + One
# + two

# %% [markdown]
# # 7 - Line breaks or page break

# %% [markdown]
# ---

# %% [markdown]
# ___

# %% [markdown]
# ***

# %% [markdown]
# # 8 - Link and Hyperlinks

# %% [markdown]
# <www.google.com>
#
# [[The Google is here whih is clickable]](www.goolgee.com)
#
# [Youtube]:www.youtube.com
#
# The social media platform is [here][Youtube]

# %% [markdown]
# # 9 - Images and Figures with link

# %% [markdown]
# To join this course please scan the following QR code
# ![QR](image2.png)
# <!-- This is a comment -->

# %% [markdown]
# # 10 - Adding code or code block
#  > To print a string use `print("This is a string)`
#
# ---
#
# ```python
# a = 12
# b = 23
# print(a + b)
# ```

# %% [markdown]
# # 11- adding Tables

# %% [markdown]
# |Specie| petal_length | sepal_length|
# |:-----: | :------: | :-----: |
# | viginica | 18.2 | 19.2 |
# | viginica | 18.2 | 19.2 |
# | viginica | 18.2 | 19.2 |

# %% [markdown]
# # 12 - Content

# %% [markdown]
# [Headings](#1---heading-1)\
# [Adding Code](#10---adding-code-or-code-block)

# %% [markdown]
# # 13 - Extensions
# > Doing with shortcuts Ctrl + B , Ctrl _ Li for link etc\
# **Bold**\
# _italic_
#
# Column A | Column B | Column C
# ---------|----------|---------
#  A1 | B1 | C1
#  A2 | B2 | C2
#  A3 | B3 | C3
